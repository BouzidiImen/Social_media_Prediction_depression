# %% [markdown]
# ## Test bit-101 model (best model) with new data from unsplash:

# %%
from models.Images_classifier import Show_pred_BIT

# %%
import tensorflow_hub as hub
# Load saved model
saved_module = hub.KerasLayer("BiT1011/", trainable=True)

# %%
from tqdm import trange
for i in trange(1,21):
    path="data/Images_test/depressed"+str(i)+".jpg"
    Show_pred_BIT.predict_image(saved_module,correct_label=0,file_path=path)
# Out:
# ...
# 100%|██████████| 20/20 [00:24<00:00,  1.25s/it]

# %%
from tqdm import trange
for i in trange(1,21):
    path="data/Images_test/happy"+str(i)+".jpg"
    Show_pred_BIT.predict_image(saved_module,correct_label=1,file_path=path)
# Out:
# ...
# 100%|██████████| 20/20 [00:24<00:00,  1.14s/it]
